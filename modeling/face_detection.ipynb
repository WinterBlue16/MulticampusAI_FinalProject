# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers import Reshape, Permute, Activation, Input, merge
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator

import sys
import os
import glob
import cv2, numpy as np
# Out:
# Using TensorFlow backend.

# %%
p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/test/E01/*.jpg') # E02, E03
# p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/train/E01/*.jpg') # E02, E03

i = 0
for img in p:
    src = cv2.imread(img)
    cascade_file = 'haarcascade_frontface.xml'
    cascade = cv2.CascadeClassifier(cascade_file)

    face_list = cascade.detectMultiScale(src)

    for (x,y,w,h) in face_list:
        print('얼굴 검출에 성공했습니다.')
        roi = src[y:y+h, x:x+w]
        if roi.shape[0] < 150 or roi.shape[1] < 150 :
            pass
#       imagex = cv2.resize(roi, (400, 400))
        else:            
            print(roi.shape)
            cv2.imwrite(f'C:/Users/user/Desktop/roi/test/E01/{i * 1}.jpg', roi) # E02, E03
#           cv2.imwrite(f'C:/Users/user/Desktop/roi/train/E01/{i * 1}.jpg', roi)
            print('사진을 저장했습니다.')
            i += 1
# Out:
# 얼굴 검출에 성공했습니다.
# (236, 236, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (233, 233, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (241, 241, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (250, 250, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (238, 238, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (253, 253, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (228, 228, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (268, 268, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (290, 290, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (258, 258, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (247, 247, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (239, 239, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (249, 249, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (276, 276, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (236, 236, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (264, 264, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (257, 257, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (246, 246, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (233, 233, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (228, 228, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (287, 287, 3)
# 사진을 저장했습니다.
# ...

# %%
p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/test/E02/*.jpg') # E02, E03
# p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/train/E01/*.jpg') # E02, E03

i = 0
for img in p:
    src = cv2.imread(img)
    cascade_file = 'haarcascade_frontface.xml'
    cascade = cv2.CascadeClassifier(cascade_file)

    face_list = cascade.detectMultiScale(src)

    for (x,y,w,h) in face_list:
        print('얼굴 검출에 성공했습니다.')
        roi = src[y:y+h, x:x+w]
        if roi.shape[0] < 150 or roi.shape[1] < 150 :
            pass
#       imagex = cv2.resize(roi, (400, 400))
        else:            
            print(roi.shape)
            cv2.imwrite(f'C:/Users/user/Desktop/roi/test/E02/{i * 1}.jpg', roi) # E02, E03
#           cv2.imwrite(f'C:/Users/user/Desktop/roi/train/E01/{i * 1}.jpg', roi)
            print('사진을 저장했습니다.')
            i += 1
# Out:
# 얼굴 검출에 성공했습니다.
# (237, 237, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (282, 282, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (246, 246, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (270, 270, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (217, 217, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (291, 291, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (230, 230, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (271, 271, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (243, 243, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (262, 262, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (243, 243, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (234, 234, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (243, 243, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (256, 256, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (263, 263, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (218, 218, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (239, 239, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (259, 259, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (269, 269, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (242, 242, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (261, 261, 3)
# 사진을 저장했습니다.
# ...

# %%
p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/test/E03/*.jpg') # E02, E03
# p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/train/E01/*.jpg') # E02, E03

i = 0
for img in p:
    src = cv2.imread(img)
    cascade_file = 'haarcascade_frontface.xml'
    cascade = cv2.CascadeClassifier(cascade_file)

    face_list = cascade.detectMultiScale(src)

    for (x,y,w,h) in face_list:
        print('얼굴 검출에 성공했습니다.')
        roi = src[y:y+h, x:x+w]
        if roi.shape[0] < 150 or roi.shape[1] < 150 :
            pass
#       imagex = cv2.resize(roi, (400, 400))
        else:            
            print(roi.shape)
            cv2.imwrite(f'C:/Users/user/Desktop/roi/test/E03/{i * 1}.jpg', roi) # E02, E03
#           cv2.imwrite(f'C:/Users/user/Desktop/roi/train/E01/{i * 1}.jpg', roi)
            print('사진을 저장했습니다.')
            i += 1
# Out:
# 얼굴 검출에 성공했습니다.
# (292, 292, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (263, 263, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (235, 235, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (260, 260, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (250, 250, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (242, 242, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (263, 263, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (257, 257, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (235, 235, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (246, 246, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (270, 270, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (248, 248, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (244, 244, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (226, 226, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (274, 274, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (254, 254, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# 얼굴 검출에 성공했습니다.
# (222, 222, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (239, 239, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (226, 226, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (225, 225, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (280, 280, 3)
# ...

# %%
# p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/test/E01/*.jpg') # E02, E03
p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/train/E01/*.jpg') # E02, E03

i = 0
for img in p:
    src = cv2.imread(img)
    cascade_file = 'haarcascade_frontface.xml'
    cascade = cv2.CascadeClassifier(cascade_file)

    face_list = cascade.detectMultiScale(src)

    for (x,y,w,h) in face_list:
        print('얼굴 검출에 성공했습니다.')
        roi = src[y:y+h, x:x+w]
        if roi.shape[0] < 150 or roi.shape[1] < 150 :
            pass
#       imagex = cv2.resize(roi, (400, 400))
        else:            
            print(roi.shape)
#           cv2.imwrite(f'C:/Users/user/Desktop/roi/test/E01/{i * 1}.jpg', roi) # E02, E03
            cv2.imwrite(f'C:/Users/user/Desktop/roi/train/E01/{i * 1}.jpg', roi)
            print('사진을 저장했습니다.')
            i += 1
# Out:
# 얼굴 검출에 성공했습니다.
# (278, 278, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (270, 270, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (238, 238, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (247, 247, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (258, 258, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (222, 222, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (259, 259, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (251, 251, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (243, 243, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (270, 270, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (273, 273, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (256, 256, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (250, 250, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (241, 241, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (208, 208, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (237, 237, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (250, 250, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (257, 257, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (292, 292, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (244, 244, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (272, 272, 3)
# 사진을 저장했습니다.
# ...

# %%
# p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/test/E01/*.jpg') # E02, E03
p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/train/E02/*.jpg') # E02, E03

i = 0
for img in p:
    src = cv2.imread(img)
    cascade_file = 'haarcascade_frontface.xml'
    cascade = cv2.CascadeClassifier(cascade_file)

    # 이전 프레임과 비교를 위해 흑백으로 변환
#     gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
    face_list = cascade.detectMultiScale(src)

    for (x,y,w,h) in face_list:
        print('얼굴 검출에 성공했습니다.')
        roi = src[y:y+h, x:x+w]
        if roi.shape[0] < 150 or roi.shape[1] < 150 :
            pass
#       imagex = cv2.resize(roi, (400, 400))
        else:            
            print(roi.shape)
#           cv2.imwrite(f'C:/Users/user/Desktop/roi/test/E01/{i * 1}.jpg', roi) # E02, E03
            cv2.imwrite(f'C:/Users/user/Desktop/roi/train/E02/{i * 1}.jpg', roi)
            print('사진을 저장했습니다.')
            i += 1
# Out:
# 얼굴 검출에 성공했습니다.
# (251, 251, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (275, 275, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (251, 251, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (213, 213, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (261, 261, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (239, 239, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (269, 269, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (286, 286, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (253, 253, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (250, 250, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (256, 256, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (241, 241, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (254, 254, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (196, 196, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (259, 259, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (263, 263, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (226, 226, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (263, 263, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (268, 268, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (252, 252, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (288, 288, 3)
# 사진을 저장했습니다.
# ...

# %%
# p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/test/E01/*.jpg') # E02, E03
p = glob.glob('C:/Users/user/Desktop/dataset_imageprocessing/train/E03/*.jpg') # E02, E03

i = 0
for img in p:
    src = cv2.imread(img)
    cascade_file = 'haarcascade_frontface.xml'
    cascade = cv2.CascadeClassifier(cascade_file)

    face_list = cascade.detectMultiScale(src)

    for (x,y,w,h) in face_list:
        print('얼굴 검출에 성공했습니다.')
        roi = src[y:y+h, x:x+w]
        if roi.shape[0] < 150 or roi.shape[1] < 150 :
            pass
#       imagex = cv2.resize(roi, (400, 400))
        else:            
            print(roi.shape)
#           cv2.imwrite(f'C:/Users/user/Desktop/roi/test/E01/{i * 1}.jpg', roi) # E02, E03
            cv2.imwrite(f'C:/Users/user/Desktop/roi/train/E03/{i * 1}.jpg', roi)
            print('사진을 저장했습니다.')
            i += 1
# Out:
# 얼굴 검출에 성공했습니다.
# 얼굴 검출에 성공했습니다.
# (232, 232, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (239, 239, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (296, 296, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (240, 240, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (252, 252, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (267, 267, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (221, 221, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (229, 229, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (268, 268, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (202, 202, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (257, 257, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (246, 246, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (256, 256, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (259, 259, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (266, 266, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (278, 278, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (278, 278, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (211, 211, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (234, 234, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (243, 243, 3)
# 사진을 저장했습니다.
# 얼굴 검출에 성공했습니다.
# (259, 259, 3)
# ...

# %%
print(sys.version)
# Out:
# 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
